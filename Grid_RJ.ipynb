# %% [markdown]
# # Aquisição Automática de Imagens com Grade (Grid)

# %% [markdown]
# ## Instalação das Bibliotecas

# %%
#!pip install earthengine-api --quiet
#!pip install rasterio --quiet
#!pip install geopandas --quiet
#!pip install requests --quiet
#!pip install folium --quiet

# %% [markdown]
# ## Importações

# %%
import ee
import os
import random
import datetime
import numpy as np
import rasterio
from rasterio import features
import geopandas as gpd
from shapely.geometry import box
import shutil
import requests
import json
import folium

# %% [markdown]
# ## Montagem do Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Autenticação para o Google Earth Engine

# %%
try:
  ee.Authenticate()
  ee.Initialize(project='761409644000')    # Substitua pelo seu ID de projeto do GEE
  print("Google Earth Engine inicializado com sucesso.")
except Exception as e:
  print(f"Erro ao inicializar o Google Earth Engine: {e}")
  print("Por favor, certifique-se de ter executado 'ee.Authenticate()' e seguido as instruções.")
  exit()
# Out:
# Google Earth Engine inicializado com sucesso.

# %% [markdown]
# ## Parâmetros

# %%
# --- Parâmetros de Download ---
output_folder_drive = "grid_rj" # Nome da pasta no Google Drive para salvar as imagens
area_size_meters = 1000 # Tamanho da célula da grade em metros (1000m = 1km)
start_date = "2023-01-01"
end_date = "2024-12-31"
max_cloud_coverage_s2 = 20 # Cobertura máxima de nuvens para Sentinel-2 (em %)
output_scale_meters = 10 # Resolução da imagem de saída em metros por pixel

# --- Parâmetros para a Grade (Grid) ---
# ATENÇÃO: Coloque abaixo o nome exato do seu arquivo .shp que você fez upload para o Colab
shapefile_path = '/content/drive/MyDrive/grid_rj/Mun_RJ.shp'
# ATENÇÃO: Nome EXATO do município como está na tabela de atributos do shapefile
municipality_to_process = 'RIO DE JANEIRO'

# Cria o diretório de saída, se não existir
os.makedirs(output_folder_drive, exist_ok=True)

# Nome do arquivo de saída para a grade
output_grid_filename = f"grid_{municipality_to_process.replace(' ', '_')}_{area_size_meters}m.shp"

# %% [markdown]
# ## Funções Auxiliares

# %%
def create_grid_for_municipality(aoi_shapefile_path, municipality_name, cell_size_meters):
    """
    Cria uma grade de polígonos sobre um MUNICÍPIO específico a partir de um shapefile.

    Args:
        aoi_shapefile_path (str): O caminho para o arquivo shapefile dos municípios.
        municipality_name (str): O nome do município para filtrar a AOI (ex: 'Rio de Janeiro').
        cell_size_meters (float): O tamanho do lado de cada célula da grade, em metros.

    Returns:
        geopandas.GeoDataFrame: Um GeoDataFrame contendo a grade de polígonos
                                que se sobrepõe ao município.
    """
    print(f"A criar grade para o município de '{municipality_name}'...")

    try:
        brasil_gdf = gpd.read_file(aoi_shapefile_path)
    except Exception as e:
        print(f"ERRO ao ler o shapefile: {e}")
        print(f"Verifique se o arquivo '{shapefile_path}' (e seus arquivos auxiliares .shx, .dbf etc.) foi carregado corretamente.")
        return None

    # Tenta filtrar pela coluna 'NM_MUN'. Se não existir, avisa o usuário.
    if 'NM_MUNICIP' not in brasil_gdf.columns:
        print("ERRO: A coluna 'NM_MUNICIP' não foi encontrada no shapefile. Verifique o nome da coluna que contém os nomes dos municípios.")
        return None

    municipality_gdf = brasil_gdf[brasil_gdf['NM_MUNICIP'] == municipality_name]

    if municipality_gdf.empty:
        print(f"ERRO: Município '{municipality_name}' não encontrado. Verifique se o nome está escrito exatamente como na tabela do shapefile.")
        return None

    municipality_geometry = municipality_gdf.unary_union
    municipality_utm = gpd.GeoSeries([municipality_geometry], crs="EPSG:4674").to_crs("EPSG:31983")
    min_x, min_y, max_x, max_y = municipality_utm.total_bounds

    x_coords = np.arange(min_x, max_x + cell_size_meters, cell_size_meters)
    y_coords = np.arange(min_y, max_y + cell_size_meters, cell_size_meters)

    grid_cells = [box(x, y, x + cell_size_meters, y + cell_size_meters) for x in x_coords for y in y_coords]
    grid_gdf_utm = gpd.GeoDataFrame(geometry=grid_cells, crs="EPSG:31983")

    municipality_gdf_utm = gpd.GeoDataFrame(geometry=municipality_utm, crs="EPSG:31983")
    intersecting_grid = gpd.sjoin(grid_gdf_utm, municipality_gdf_utm, how="inner", predicate="intersects")

    intersecting_grid = intersecting_grid.drop_duplicates('geometry')
    grid_wgs84 = intersecting_grid.to_crs("EPSG:4674")

    print(f"Grade criada com {len(grid_wgs84)} células de {cell_size_meters}x{cell_size_meters} metros.")
    return grid_wgs84

# %% [markdown]
# ## Funções de Download do Sentinel

# %%
def mask_s2_clouds(image):
    qa = image.select('QA60')
    cloud_bit_mask = 1 << 10
    cirrus_bit_mask = 1 << 11
    mask = qa.bitwiseAnd(cloud_bit_mask).eq(0).And(qa.bitwiseAnd(cirrus_bit_mask).eq(0))
    return image.updateMask(mask).divide(10000)

def get_sentinel2_image(geometry, start_date, end_date, max_cloud_coverage):
    s2_collection = ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED') \
        .filterBounds(geometry) \
        .filterDate(start_date, end_date) \
        .filter(ee.Filter.lte('CLOUDY_PIXEL_PERCENTAGE', max_cloud_coverage)) \
        .map(mask_s2_clouds)

    if s2_collection.size().getInfo() == 0:
        return None

    s2_image = s2_collection.median().select(['B4', 'B3', 'B2', 'B8'])
    return s2_image if s2_image.bandNames().size().getInfo() > 0 else None

def get_sentinel1_image(geometry, start_date, end_date):
    s1_collection = ee.ImageCollection('COPERNICUS/S1_GRD_FLOAT') \
        .filterBounds(geometry) \
        .filterDate(start_date, end_date) \
        .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VV')) \
        .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VH')) \
        .filter(ee.Filter.eq('orbitProperties_pass', 'DESCENDING')) \
        .filter(ee.Filter.eq('resolution_meters', 10))

    if s1_collection.size().getInfo() == 0:
        return None

    s1_image = s1_collection.median().select(['VV', 'VH'])
    return s1_image if s1_image.bandNames().size().getInfo() > 0 else None

# %% [markdown]
# ## Funções da Máscara OSM

# %%
def get_geojson_from_overpass(geometry):
    coords_info = geometry.bounds().getInfo()['coordinates'][0]
    min_lon = min(p[0] for p in coords_info)
    min_lat = min(p[1] for p in coords_info)
    max_lon = max(p[0] for p in coords_info)
    max_lat = max(p[1] for p in coords_info)

    overpass_bbox = f"{min_lat},{min_lon},{max_lat},{max_lon}"
    overpass_url = "http://overpass-api.de/api/interpreter"
    overpass_query = f"""
    [out:json][timeout:60];
    (
      way["highway"~"^(primary|secondary|tertiary|residential)$"]({overpass_bbox});
    );
    (._;>;);
    out body;
    """

    try:
        response = requests.post(overpass_url, data={'data': overpass_query})
        response.raise_for_status()
        data = response.json()

        geojson_features = []
        if 'elements' in data and len(data['elements']) > 0:
            node_coords = {str(elem['id']): (elem['lon'], elem['lat']) for elem in data['elements'] if elem['type'] == 'node'}
            for element in data['elements']:
                if element['type'] == 'way':
                    coords_list = [node_coords.get(str(node_id)) for node_id in element['nodes'] if str(node_id) in node_coords]
                    if len(coords_list) >= 2:
                        feature = {
                            "type": "Feature", "properties": element.get('tags', {}),
                            "geometry": {"type": "LineString", "coordinates": coords_list}
                        }
                        geojson_features.append(feature)

        return geojson_features if geojson_features else None
    except Exception as e:
        print(f"Erro na API Overpass: {e}")
        return None

def get_rasterized_road_network_gee(geometry, scale_meters, area_name, output_folder_drive, geojson_features):
    if not geojson_features:
        print(f"Não há dados GeoJSON válidos para rasterizar para a área {area_name}.")
        return None
    try:
        ee_features = [ee.Feature(f) for f in geojson_features]
        road_feature_collection = ee.FeatureCollection(ee_features).map(lambda f: f.set('value', 1))

        empty_image = ee.Image(0).rename('roads').float()
        rasterized_roads_gee = empty_image.paint(road_feature_collection, 'value')

        description = f"mask_{area_name}"
        task = ee.batch.Export.image.toDrive(
            image=rasterized_roads_gee, description=description, folder=output_folder_drive,
            scale=scale_meters, region=geometry.bounds().getInfo()['coordinates'],
            fileFormat='GeoTIFF', formatOptions={'cloudOptimized': True}
        )
        task.start()
        print(f"Tarefa de Máscara '{description}' iniciada. ID: {task.id}")
        return task.id
    except Exception as e:
        print(f"Erro ao rasterizar rede viária com GEE: {e}")
        return None

# %% [markdown]
# ## Geração e Exportação das Imagens

# %%
# --- INÍCIO DO PROCESSO PRINCIPAL ---

# 1. Criar a grade para o município de interesse
grid_gdf = create_grid_for_municipality(shapefile_path, municipality_to_process, area_size_meters)

if grid_gdf is not None:
    print(f"\nIniciando o processo de exportação para as {len(grid_gdf)} células da grade.")
    print(f"As imagens serão baixadas APENAS para as células que contiverem rodovias.")
    print(f"Os arquivos serão salvos na pasta '{output_folder_drive}' no seu Google Drive.")
    print("Monitore o progresso na aba 'Tasks' do Google Earth Engine Code Editor.")

    # Salvar .shp do grid gerado
    try:
        grid_para_salvar.to_file(output_grid_filename)
        print(f"✅ Arquivo da grade salvo com sucesso como '{output_grid_filename}'")
        print("   Atualize a lista de arquivos (à esquerda) para ver o resultado.")
    except Exception as e:
        print(f"❌ Erro ao salvar o arquivo da grade: {e}")

    # 2. Loop principal que itera sobre cada célula da grade
    for index, cell in grid_gdf.iterrows():
        print(f"\n--- Analisando Célula {index + 1}/{len(grid_gdf)} ---")

        # Converte a geometria da célula para um ee.Geometry
        coords = list(cell.geometry.exterior.coords)
        area_geometry = ee.Geometry.Polygon(coords)

        # Verifica se existem rodovias na célula antes de continuar
        geojson_features = get_geojson_from_overpass(area_geometry)

        if not geojson_features:
            print(f"Nenhuma rodovia encontrada na Célula {index + 1}. Pulando para a próxima...")
            continue

        # Se encontrou rodovias, inicia as tarefas de download
        print(f"Rodovias encontradas! Iniciando tarefas de download para a célula {index + 1}.")

        current_area_name = f"grid_cell_{index}"

        # Tarefa da Máscara de Rodovias
        get_rasterized_road_network_gee(area_geometry, output_scale_meters, current_area_name, output_folder_drive, geojson_features)

        # Tarefa do Sentinel-2
        s2_image_to_export = get_sentinel2_image(area_geometry, start_date, end_date, max_cloud_coverage_s2)
        if s2_image_to_export:
            s2_image_to_export = s2_image_to_export.clip(area_geometry)
            s2_description = f"sentinel2_{current_area_name}"
            s2_task = ee.batch.Export.image.toDrive(
                image=s2_image_to_export, description=s2_description, folder=output_folder_drive,
                scale=output_scale_meters, region=area_geometry.getInfo()['coordinates']
            )
            s2_task.start()
            print(f"Tarefa Sentinel-2 '{s2_description}' iniciada. ID: {s2_task.id}")
        else:
            print(f"Nenhuma imagem Sentinel-2 encontrada para a célula {index + 1}.")

        # Tarefa do Sentinel-1
        s1_image_to_export = get_sentinel1_image(area_geometry, start_date, end_date)
        if s1_image_to_export:
            s1_image_to_export = s1_image_to_export.clip(area_geometry)
            s1_description = f"sentinel1_{current_area_name}"
            s1_task = ee.batch.Export.image.toDrive(
                image=s1_image_to_export, description=s1_description, folder=output_folder_drive,
                scale=output_scale_meters, region=area_geometry.getInfo()['coordinates']
            )
            s1_task.start()
            print(f"Tarefa Sentinel-1 '{s1_description}' iniciada. ID: {s1_task.id}")
        else:
            print(f"Nenhuma imagem Sentinel-1 encontrada para a célula {index + 1}.")

    print("\nProcesso de inicialização de tarefas concluído para todas as células relevantes da grade!")
    print("Verifique o seu Google Drive e a aba 'Tasks' do Earth Engine para os resultados.")

else:
    print("\nA execução foi interrompida porque a grade não pôde ser criada.")
# Out:
# A criar grade para o município de 'RIO DE JANEIRO'...
# /tmp/ipython-input-1411351449.py:34: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   municipality_geometry = municipality_gdf.unary_union
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Rodovias encontradas! Iniciando tarefas de download para a célula 1016.
# Tarefa de Máscara 'mask_grid_cell_1015' iniciada. ID: 5BGXZBMZDGI5VS22SFVELDS4
# Tarefa Sentinel-2 'sentinel2_grid_cell_1015' iniciada. ID: OB32HCW2466GGTZDGAFEHC7N
# Tarefa Sentinel-1 'sentinel1_grid_cell_1015' iniciada. ID: H7HOQJ5X4FUJXSZDRCIHCGI6
#
# --- Analisando Célula 1017/1404 ---
# Nenhuma rodovia encontrada na Célula 1017. Pulando para a próxima...
#
# --- Analisando Célula 1030/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1030.
# Tarefa de Máscara 'mask_grid_cell_1029' iniciada. ID: YL6UUPXPZQOSWBEMGALJP3RF
# Tarefa Sentinel-2 'sentinel2_grid_cell_1029' iniciada. ID: RJUSWRJK4KJ7Y63YAFNV2HXQ
# Tarefa Sentinel-1 'sentinel1_grid_cell_1029' iniciada. ID: XW6PNJO7BJ3LYBLCONZODHLZ
#
# --- Analisando Célula 1031/1404 ---
# Nenhuma rodovia encontrada na Célula 1031. Pulando para a próxima...
#
# --- Analisando Célula 1032/1404 ---
# Nenhuma rodovia encontrada na Célula 1032. Pulando para a próxima...
#
# --- Analisando Célula 1033/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1033.
# Tarefa de Máscara 'mask_grid_cell_1032' iniciada. ID: 3IUTOWVWETZKCPZJZZWLX3RQ
# Tarefa Sentinel-2 'sentinel2_grid_cell_1032' iniciada. ID: OTO7LDRLKI6MJRNPKFG2MDIE
# Tarefa Sentinel-1 'sentinel1_grid_cell_1032' iniciada. ID: Q5HGYTK4DP3ZVWSANSPO5P4G
#
# --- Analisando Célula 1034/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1034.
# Tarefa de Máscara 'mask_grid_cell_1033' iniciada. ID: 2X6442FHUBB6A7SKGKVVGNG7
# Tarefa Sentinel-2 'sentinel2_grid_cell_1033' iniciada. ID: 74IFQH3ZIIZ2Q23ZCZR7TQRK
# Tarefa Sentinel-1 'sentinel1_grid_cell_1033' iniciada. ID: HJXATQ6FGUOHY5WLUDT2J53D
#
# --- Analisando Célula 1035/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1035.
# Tarefa de Máscara 'mask_grid_cell_1034' iniciada. ID: 7VHISZQR67A6W6EDZN6LQZMX
# Tarefa Sentinel-2 'sentinel2_grid_cell_1034' iniciada. ID: 6VJKHIWXVA22G5LKVMBZNXHE
# Tarefa Sentinel-1 'sentinel1_grid_cell_1034' iniciada. ID: J2AMCKEQVTBH72T2WNTCF7NN
#
# --- Analisando Célula 1036/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1036.
# Tarefa de Máscara 'mask_grid_cell_1035' iniciada. ID: IV64PV4OURT5V6PQC4GVTLYE
# Tarefa Sentinel-2 'sentinel2_grid_cell_1035' iniciada. ID: STUOZU77BIXRKOAER7VWBEZS
# Tarefa Sentinel-1 'sentinel1_grid_cell_1035' iniciada. ID: ZFG4N64BF3GPBVQU6KK2PV55
#
# --- Analisando Célula 1037/1404 ---
# Nenhuma rodovia encontrada na Célula 1037. Pulando para a próxima...
#
# --- Analisando Célula 1038/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1038.
# Tarefa de Máscara 'mask_grid_cell_1037' iniciada. ID: A2IUJ4TVB2ZICL3ZN6RAOFT6
# Tarefa Sentinel-2 'sentinel2_grid_cell_1037' iniciada. ID: YHR3JZ43B6M4UQYHWFB4BTTH
# Tarefa Sentinel-1 'sentinel1_grid_cell_1037' iniciada. ID: RQHJJTHWP2W3K6WXAQACIFJ3
#
# --- Analisando Célula 1039/1404 ---
# Nenhuma rodovia encontrada na Célula 1039. Pulando para a próxima...
#
# --- Analisando Célula 1040/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1040.
# Tarefa de Máscara 'mask_grid_cell_1039' iniciada. ID: UERA6BG44IYNTIYL5GFZHD2W
# Tarefa Sentinel-2 'sentinel2_grid_cell_1039' iniciada. ID: GNM5ZVRUZSAVRWQB75DBX37F
# Tarefa Sentinel-1 'sentinel1_grid_cell_1039' iniciada. ID: DT3MRZFSNHZVNVAUP66YABHI
#
# --- Analisando Célula 1041/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1041.
# Tarefa de Máscara 'mask_grid_cell_1040' iniciada. ID: U4NWTMPH4LLZXUJYSRPSHLOD
# Tarefa Sentinel-2 'sentinel2_grid_cell_1040' iniciada. ID: LPY6KBSP4H6BNUEHTB7DRON4
# Tarefa Sentinel-1 'sentinel1_grid_cell_1040' iniciada. ID: ICX5ZL7GHPFBKB2NYMQWNNCK
#
# --- Analisando Célula 1042/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1042.
# Tarefa de Máscara 'mask_grid_cell_1041' iniciada. ID: KVF2YEURJM3K2MZZ7YHPVGV6
# Tarefa Sentinel-2 'sentinel2_grid_cell_1041' iniciada. ID: TZ776KXAQ6T2S7QGDFOTENKZ
# Tarefa Sentinel-1 'sentinel1_grid_cell_1041' iniciada. ID: 2AHJFRIIG27UQ5GBE6T52IQQ
#
# --- Analisando Célula 1043/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1043.
# Tarefa de Máscara 'mask_grid_cell_1042' iniciada. ID: FDYE2SGPSJ45VNLUKF2TBYPL
# Tarefa Sentinel-2 'sentinel2_grid_cell_1042' iniciada. ID: TIDSRVS2URLT35YLIXOZK747
# Tarefa Sentinel-1 'sentinel1_grid_cell_1042' iniciada. ID: 6HT5FTGM3EITMJB66BVNNRBR
#
# --- Analisando Célula 1044/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1044.
# Tarefa de Máscara 'mask_grid_cell_1043' iniciada. ID: 6FJLFCGFLZRMGRUARDUYD2DI
# Tarefa Sentinel-2 'sentinel2_grid_cell_1043' iniciada. ID: G4DRVUZXGQE63VGJOBWVQMD5
# Tarefa Sentinel-1 'sentinel1_grid_cell_1043' iniciada. ID: QUBMNVLFFUFICPIWJKYOPT5I
#
# --- Analisando Célula 1045/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1045.
# Tarefa de Máscara 'mask_grid_cell_1044' iniciada. ID: CK2463ZDSRKAZAQBTSBEGDBO
# Tarefa Sentinel-2 'sentinel2_grid_cell_1044' iniciada. ID: M2RZKNIZVH3RK4VC5DWPMCPA
# Tarefa Sentinel-1 'sentinel1_grid_cell_1044' iniciada. ID: TVTXCWVE6CQGN44HHJQO3QL4
#
# --- Analisando Célula 1046/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1046.
# Tarefa de Máscara 'mask_grid_cell_1045' iniciada. ID: 3MTUDP2RLSA4JLIHJ44J7IZW
# Tarefa Sentinel-2 'sentinel2_grid_cell_1045' iniciada. ID: GLB2OZIMTPP4YMUGASDJJFLF
# Tarefa Sentinel-1 'sentinel1_grid_cell_1045' iniciada. ID: NIUK5HSHMZUIJFDOX3C43JT7
#
# --- Analisando Célula 1047/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1047.
# Tarefa de Máscara 'mask_grid_cell_1046' iniciada. ID: 52FRGBDG2QTAM3YUYZHI6PQG
# Tarefa Sentinel-2 'sentinel2_grid_cell_1046' iniciada. ID: 5VN6MX7JAVEIWFKP544MTMKC
# Tarefa Sentinel-1 'sentinel1_grid_cell_1046' iniciada. ID: LHBENOSCKO777PGOTIB5BEKR
#
# --- Analisando Célula 1048/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1048.
# Tarefa de Máscara 'mask_grid_cell_1047' iniciada. ID: DYLQYTL7QHSAUGUYIAGH2VQK
# Tarefa Sentinel-2 'sentinel2_grid_cell_1047' iniciada. ID: 7Y6DN66O74IXVR2S34QYOGBZ
# Tarefa Sentinel-1 'sentinel1_grid_cell_1047' iniciada. ID: KPOZMRKPQYRDYJ3CXL7SJ5N3
#
# --- Analisando Célula 1049/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1049.
# Tarefa de Máscara 'mask_grid_cell_1048' iniciada. ID: Q3GHL4HXDE4WI5NFQ5YIB44Q
# Tarefa Sentinel-2 'sentinel2_grid_cell_1048' iniciada. ID: 3XZST5OAYOD5EDPN4EI2J7TJ
# Tarefa Sentinel-1 'sentinel1_grid_cell_1048' iniciada. ID: FFQZM5CD2EUXNLUBDJT3SK2G
#
# --- Analisando Célula 1050/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1050.
# Tarefa de Máscara 'mask_grid_cell_1049' iniciada. ID: 3WILUASMQ3FUGYR5P4E7UGVA
# Tarefa Sentinel-2 'sentinel2_grid_cell_1049' iniciada. ID: 3IJLJJ5H6YEBDRVGTNFSFAD4
# Tarefa Sentinel-1 'sentinel1_grid_cell_1049' iniciada. ID: YJVDEICHKIV3PGMAWGUY6DKS
#
# --- Analisando Célula 1051/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1051.
# Tarefa de Máscara 'mask_grid_cell_1050' iniciada. ID: Q5JQGE7NKWODN2DEKOLTOZEJ
# Tarefa Sentinel-2 'sentinel2_grid_cell_1050' iniciada. ID: SXLLFOAUDSU76C4CZRVKC5WY
# Tarefa Sentinel-1 'sentinel1_grid_cell_1050' iniciada. ID: M4XIATGDQNKVRYWX4Y4YENRB
#
# --- Analisando Célula 1052/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1052.
# Tarefa de Máscara 'mask_grid_cell_1051' iniciada. ID: JRZ3XQ57XX7M2DRNCIOKUYMM
# Tarefa Sentinel-2 'sentinel2_grid_cell_1051' iniciada. ID: Z3CWUTZFQW2BMVQLPZ5EZHGJ
# Tarefa Sentinel-1 'sentinel1_grid_cell_1051' iniciada. ID: UTFX2ATMPZP3FYKUNVUEGERO
#
# --- Analisando Célula 1053/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1053.
# Tarefa de Máscara 'mask_grid_cell_1052' iniciada. ID: KX3JIGNENTQWRJ2F3LYMDLLV
# Tarefa Sentinel-2 'sentinel2_grid_cell_1052' iniciada. ID: 7ZCZMCZPI6VERGXTSHO6SL5B
# Tarefa Sentinel-1 'sentinel1_grid_cell_1052' iniciada. ID: J4BKVHMWHL2YHHY2ZYXWMIRQ
#
# --- Analisando Célula 1054/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1054.
# Tarefa de Máscara 'mask_grid_cell_1053' iniciada. ID: 5FCPCG24VBPNX56HTHGW4SAH
# Tarefa Sentinel-2 'sentinel2_grid_cell_1053' iniciada. ID: J3S7FKNLBRGEEB5DPK7DDJ7J
# Tarefa Sentinel-1 'sentinel1_grid_cell_1053' iniciada. ID: TADWNLRME3N6VDG3N2AVCAYB
#
# --- Analisando Célula 1055/1404 ---
# Nenhuma rodovia encontrada na Célula 1055. Pulando para a próxima...
#
# --- Analisando Célula 1066/1404 ---
# Nenhuma rodovia encontrada na Célula 1066. Pulando para a próxima...
#
# --- Analisando Célula 1067/1404 ---
# Nenhuma rodovia encontrada na Célula 1067. Pulando para a próxima...
#
# --- Analisando Célula 1068/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1068.
# Tarefa de Máscara 'mask_grid_cell_1067' iniciada. ID: NEUEWQ7JALHK7ON5UD44VQWX
# Tarefa Sentinel-2 'sentinel2_grid_cell_1067' iniciada. ID: 6R4EEJUO3NVE6DY5D6RGPI6H
# Tarefa Sentinel-1 'sentinel1_grid_cell_1067' iniciada. ID: WUR3TMVFWK76VAV5UIO2YZIY
#
# --- Analisando Célula 1069/1404 ---
# Nenhuma rodovia encontrada na Célula 1069. Pulando para a próxima...
#
# --- Analisando Célula 1070/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1070.
# Tarefa de Máscara 'mask_grid_cell_1069' iniciada. ID: QDQUALFON7R7JA56WN5IGK2V
# Tarefa Sentinel-2 'sentinel2_grid_cell_1069' iniciada. ID: 3WCEOQTL2GXXP6GAD6FPN3OO
# Tarefa Sentinel-1 'sentinel1_grid_cell_1069' iniciada. ID: CTUFDLYXXIONL3K6DMBXBEG6
#
# --- Analisando Célula 1071/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1071.
# Tarefa de Máscara 'mask_grid_cell_1070' iniciada. ID: 5Y4CXM7TP3CZDJSU37E3Z25N
# Tarefa Sentinel-2 'sentinel2_grid_cell_1070' iniciada. ID: 3XXLPAKZQ4N7T66H7PHPOE2U
# Tarefa Sentinel-1 'sentinel1_grid_cell_1070' iniciada. ID: YEVP446DIBGMJSOAOTK4NRB5
#
# --- Analisando Célula 1072/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1072.
# Tarefa de Máscara 'mask_grid_cell_1071' iniciada. ID: ARQRSGRNQNUVDI4VSNBP4D62
# Tarefa Sentinel-2 'sentinel2_grid_cell_1071' iniciada. ID: 5UAL4ESPN54XZHV5IXM6XTP7
# Tarefa Sentinel-1 'sentinel1_grid_cell_1071' iniciada. ID: KDBIIHRDMIASH6KFFX5NZBEY
#
# --- Analisando Célula 1073/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1073.
# Tarefa de Máscara 'mask_grid_cell_1072' iniciada. ID: NYGZ7OBIZGX5MLZOT5TMATZW
# Tarefa Sentinel-2 'sentinel2_grid_cell_1072' iniciada. ID: 64C4PSRZ5BR6U4DQWIYJQE4Z
# Tarefa Sentinel-1 'sentinel1_grid_cell_1072' iniciada. ID: D4HLYR7MAKALHITLZFYYZ77W
#
# --- Analisando Célula 1074/1404 ---
# Nenhuma rodovia encontrada na Célula 1074. Pulando para a próxima...
#
# --- Analisando Célula 1075/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1075.
# Tarefa de Máscara 'mask_grid_cell_1074' iniciada. ID: TU6YSXXNMCSCE7TCHPYI6AOQ
# Tarefa Sentinel-2 'sentinel2_grid_cell_1074' iniciada. ID: KCR7GPWY5JXJYYGL674XQTHS
# Tarefa Sentinel-1 'sentinel1_grid_cell_1074' iniciada. ID: RAHUOKCLDPUMV2TJ32OOTNHO
#
# --- Analisando Célula 1076/1404 ---
# Nenhuma rodovia encontrada na Célula 1076. Pulando para a próxima...
#
# --- Analisando Célula 1077/1404 ---
# Nenhuma rodovia encontrada na Célula 1077. Pulando para a próxima...
#
# --- Analisando Célula 1078/1404 ---
# Nenhuma rodovia encontrada na Célula 1078. Pulando para a próxima...
#
# --- Analisando Célula 1079/1404 ---
# Nenhuma rodovia encontrada na Célula 1079. Pulando para a próxima...
#
# --- Analisando Célula 1080/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1080.
# Tarefa de Máscara 'mask_grid_cell_1079' iniciada. ID: GBWP2IGADJVWTYSJWUBJP73M
# Tarefa Sentinel-2 'sentinel2_grid_cell_1079' iniciada. ID: DEETOJNZK7PFFSBH6W5GOWTV
# Tarefa Sentinel-1 'sentinel1_grid_cell_1079' iniciada. ID: AQNGMAU2NPGUOC2O32Q6T5YQ
#
# --- Analisando Célula 1081/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1081.
# Tarefa de Máscara 'mask_grid_cell_1080' iniciada. ID: EHREVU4VBCNGV2S2PJ67EHJU
# Tarefa Sentinel-2 'sentinel2_grid_cell_1080' iniciada. ID: QPVV47CGC3ZZLTOZ4FOL4MSZ
# Tarefa Sentinel-1 'sentinel1_grid_cell_1080' iniciada. ID: JRAQWLWZVZ27UHXWRRBHWC4S
#
# --- Analisando Célula 1082/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1082.
# Tarefa de Máscara 'mask_grid_cell_1081' iniciada. ID: NV7FU7E7FZNNE3SJ2JOHWJ7T
# Tarefa Sentinel-2 'sentinel2_grid_cell_1081' iniciada. ID: TYCWCQVIQLL2XUWJMQQICEMT
# Tarefa Sentinel-1 'sentinel1_grid_cell_1081' iniciada. ID: 7Z3AHIDQ3J74VLNSS5H3RQ35
#
# --- Analisando Célula 1083/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1083.
# Tarefa de Máscara 'mask_grid_cell_1082' iniciada. ID: GNR6X4DXXR6VRSVNG7M7MCF5
# Tarefa Sentinel-2 'sentinel2_grid_cell_1082' iniciada. ID: 23HLC3FXUDMXIWASRY4A2FUQ
# Tarefa Sentinel-1 'sentinel1_grid_cell_1082' iniciada. ID: D7KY3XO4M5UH2IZ5Y7WKLOC5
#
# --- Analisando Célula 1084/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1084.
# Tarefa de Máscara 'mask_grid_cell_1083' iniciada. ID: 737KNVYLY7FOVIPNXTCXH4RP
# Tarefa Sentinel-2 'sentinel2_grid_cell_1083' iniciada. ID: WU35KFGHDBL6OPMFUHKQX3PD
# Tarefa Sentinel-1 'sentinel1_grid_cell_1083' iniciada. ID: 5B4JGNMC7Q5YOMFOLJ6BQPPF
#
# --- Analisando Célula 1085/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1085.
# Tarefa de Máscara 'mask_grid_cell_1084' iniciada. ID: LPTZ3LR5GOHKVO4JGSZ4I6MJ
# Tarefa Sentinel-2 'sentinel2_grid_cell_1084' iniciada. ID: K5LWP5TCQUJDO3UIMFR4WFB7
# Tarefa Sentinel-1 'sentinel1_grid_cell_1084' iniciada. ID: LNO362GI3OUJI3ZRRPEGU6FG
#
# --- Analisando Célula 1086/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1086.
# Tarefa de Máscara 'mask_grid_cell_1085' iniciada. ID: 22SYYEY5WKAZCK27BFJSZUMJ
# Tarefa Sentinel-2 'sentinel2_grid_cell_1085' iniciada. ID: 76OYPL5PC2EAJMVZBXSXS3LF
# Tarefa Sentinel-1 'sentinel1_grid_cell_1085' iniciada. ID: UNPCBGJCSGBCGLESOXG7YHTP
#
# --- Analisando Célula 1087/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1087.
# Tarefa de Máscara 'mask_grid_cell_1086' iniciada. ID: CBNC4JZ55ZIAI3BVUZC3LDTX
# Tarefa Sentinel-2 'sentinel2_grid_cell_1086' iniciada. ID: CD6VTLJZEXZ36E2JUH6PMZ7Z
# Tarefa Sentinel-1 'sentinel1_grid_cell_1086' iniciada. ID: KUXKNLALXJU5KKMXC6XXD2FU
#
# --- Analisando Célula 1088/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1088.
# Tarefa de Máscara 'mask_grid_cell_1087' iniciada. ID: YK43Q5PBNSGETLBO2S4ODCUC
# Tarefa Sentinel-2 'sentinel2_grid_cell_1087' iniciada. ID: UU3VKPFLC7GO44H4UOL3OPQD
# Tarefa Sentinel-1 'sentinel1_grid_cell_1087' iniciada. ID: BR2N76KLQM3VNNCG4RQJOD2Q
#
# --- Analisando Célula 1089/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1089.
# Tarefa de Máscara 'mask_grid_cell_1088' iniciada. ID: 6KSMVODZ6BDATS5WRPUOWYMD
# Tarefa Sentinel-2 'sentinel2_grid_cell_1088' iniciada. ID: IWIDBG44WURCTSTT7UBKC3LC
# Tarefa Sentinel-1 'sentinel1_grid_cell_1088' iniciada. ID: CKKO3CFJQWLI6CF466PQ6555
#
# --- Analisando Célula 1090/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1090.
# Tarefa de Máscara 'mask_grid_cell_1089' iniciada. ID: VGAOAV4UJ52VFR3VJ3D3OAPS
# Tarefa Sentinel-2 'sentinel2_grid_cell_1089' iniciada. ID: BEHHW442EGE52SELUPFNJECY
# Tarefa Sentinel-1 'sentinel1_grid_cell_1089' iniciada. ID: UX6UVPIUDHXDWO5T3CNYBVED
#
# --- Analisando Célula 1091/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1091.
# Tarefa de Máscara 'mask_grid_cell_1090' iniciada. ID: TOJP6ZKO5BXE2CWFG6AYTDJW
# Tarefa Sentinel-2 'sentinel2_grid_cell_1090' iniciada. ID: PGDROSGXBFAPTV6MR33RBSHY
# Tarefa Sentinel-1 'sentinel1_grid_cell_1090' iniciada. ID: EM2NLJNXFR2S6C2ETIMFORGC
#
# --- Analisando Célula 1092/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1092.
# Tarefa de Máscara 'mask_grid_cell_1091' iniciada. ID: 62HEN6LWYOH5OGHWYHD2IUB2
# Tarefa Sentinel-2 'sentinel2_grid_cell_1091' iniciada. ID: A2GMRJRA6AXKRPVIAJAV7IC7
# Tarefa Sentinel-1 'sentinel1_grid_cell_1091' iniciada. ID: X4ABTN7KFARHFCF7HGF5WWHN
#
# --- Analisando Célula 1093/1404 ---
# Nenhuma rodovia encontrada na Célula 1093. Pulando para a próxima...
#
# --- Analisando Célula 1104/1404 ---
# Nenhuma rodovia encontrada na Célula 1104. Pulando para a próxima...
#
# --- Analisando Célula 1105/1404 ---
# Nenhuma rodovia encontrada na Célula 1105. Pulando para a próxima...
#
# --- Analisando Célula 1106/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1106.
# Tarefa de Máscara 'mask_grid_cell_1105' iniciada. ID: 3WUG5DUAORSASZXVEKMDHS7P
# Tarefa Sentinel-2 'sentinel2_grid_cell_1105' iniciada. ID: X33E4XE4FNAR22QKUD7OABWJ
# Tarefa Sentinel-1 'sentinel1_grid_cell_1105' iniciada. ID: 4VQDWOSJM5IHASXKEKYSKQBR
#
# --- Analisando Célula 1107/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1107.
# Tarefa de Máscara 'mask_grid_cell_1106' iniciada. ID: HX3YVAZCO6VADBRQE4US4LH4
# Tarefa Sentinel-2 'sentinel2_grid_cell_1106' iniciada. ID: DHM5IQ5OVRNUIJEMP4WX3KMT
# Tarefa Sentinel-1 'sentinel1_grid_cell_1106' iniciada. ID: U22GKOJCMEF4H6O2TLE33ZIV
#
# --- Analisando Célula 1108/1404 ---
# Nenhuma rodovia encontrada na Célula 1108. Pulando para a próxima...
#
# --- Analisando Célula 1109/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1109.
# Tarefa de Máscara 'mask_grid_cell_1108' iniciada. ID: 7H2NXXVQFSK2OUBOFFJHLOAN
# Tarefa Sentinel-2 'sentinel2_grid_cell_1108' iniciada. ID: QVZRWFRWKYF5D7HO3NMCCLWU
# Tarefa Sentinel-1 'sentinel1_grid_cell_1108' iniciada. ID: 3VADTKTVMAWVLBYXAIHZNMRU
#
# --- Analisando Célula 1110/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1110.
# Tarefa de Máscara 'mask_grid_cell_1109' iniciada. ID: 4OPRKYB7JNCL3DAM22EAYPFW
# Tarefa Sentinel-2 'sentinel2_grid_cell_1109' iniciada. ID: 6B37X5WHPWLRFL4MGEIOF7EU
# Tarefa Sentinel-1 'sentinel1_grid_cell_1109' iniciada. ID: 3ELHDEOA77K2626D5OWM6BW4
#
# --- Analisando Célula 1111/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1111.
# Tarefa de Máscara 'mask_grid_cell_1110' iniciada. ID: G7LDQTWORFXIZVPNDX7WF34E
# Tarefa Sentinel-2 'sentinel2_grid_cell_1110' iniciada. ID: YUT2NPJF65QXBYBH7MZOVBUD
# Tarefa Sentinel-1 'sentinel1_grid_cell_1110' iniciada. ID: EYQOGQWONZICAFQ4C3VQFNB5
#
# --- Analisando Célula 1112/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1112.
# Tarefa de Máscara 'mask_grid_cell_1111' iniciada. ID: ZTCXD55ERLSHY4JVQFWEAW6O
# Tarefa Sentinel-2 'sentinel2_grid_cell_1111' iniciada. ID: KWKWBROZS66RHX5HY7JNZISN
# Tarefa Sentinel-1 'sentinel1_grid_cell_1111' iniciada. ID: E2DS64EYZE3QBCYTBI25GRB3
#
# --- Analisando Célula 1113/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1113.
# Tarefa de Máscara 'mask_grid_cell_1112' iniciada. ID: 5M5Y52DYGXP3SCO3IS2SXIHS
# Tarefa Sentinel-2 'sentinel2_grid_cell_1112' iniciada. ID: IPXZCDY44I5ORJDZ5ZWLUIJU
# Tarefa Sentinel-1 'sentinel1_grid_cell_1112' iniciada. ID: DUD37A4UCYCTHXYMOZMJGC5V
#
# --- Analisando Célula 1114/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1114.
# Tarefa de Máscara 'mask_grid_cell_1113' iniciada. ID: IRU3IMYE4OFTHPU45UZE2XOV
# Tarefa Sentinel-2 'sentinel2_grid_cell_1113' iniciada. ID: YTRILFN7XOSVT6TLUMA7R6PK
# Tarefa Sentinel-1 'sentinel1_grid_cell_1113' iniciada. ID: DFH7V4UUJFPWYOYMJ3TAJS7K
#
# --- Analisando Célula 1115/1404 ---
# Nenhuma rodovia encontrada na Célula 1115. Pulando para a próxima...
#
# --- Analisando Célula 1116/1404 ---
# Nenhuma rodovia encontrada na Célula 1116. Pulando para a próxima...
#
# --- Analisando Célula 1117/1404 ---
# Nenhuma rodovia encontrada na Célula 1117. Pulando para a próxima...
#
# --- Analisando Célula 1118/1404 ---
# Nenhuma rodovia encontrada na Célula 1118. Pulando para a próxima...
#
# --- Analisando Célula 1119/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1119.
# Tarefa de Máscara 'mask_grid_cell_1118' iniciada. ID: FFXOJANOQEZXNCRIZ7AA57E2
# Tarefa Sentinel-2 'sentinel2_grid_cell_1118' iniciada. ID: ADOGZ3F57ZYUM2J4QO45PUDK
# Tarefa Sentinel-1 'sentinel1_grid_cell_1118' iniciada. ID: BBYYUTE73FK6V2HVAQ7LNIZV
#
# --- Analisando Célula 1120/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1120.
# Tarefa de Máscara 'mask_grid_cell_1119' iniciada. ID: IIPIUSGUI33INGJQRTXH56J3
# Tarefa Sentinel-2 'sentinel2_grid_cell_1119' iniciada. ID: EZVVHBIZIBQYWJCSUN3C6KT7
# Tarefa Sentinel-1 'sentinel1_grid_cell_1119' iniciada. ID: ME2QXZSPYNDLDARHFO2AE4XD
#
# --- Analisando Célula 1121/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1121.
# Tarefa de Máscara 'mask_grid_cell_1120' iniciada. ID: XKBPQDDI7A6TANWT3RBAWMH2
# Tarefa Sentinel-2 'sentinel2_grid_cell_1120' iniciada. ID: J2WKI22BYBEZAKXRCFAQYBYW
# Tarefa Sentinel-1 'sentinel1_grid_cell_1120' iniciada. ID: ITAAMX3ITDMZEMZHT4M6MX4B
#
# --- Analisando Célula 1122/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1122.
# Tarefa de Máscara 'mask_grid_cell_1121' iniciada. ID: 2HTTGVOYHXRUPILZMPFAUFMX
# Tarefa Sentinel-2 'sentinel2_grid_cell_1121' iniciada. ID: 5KSYYNUSPN5JGOCW6ULUFAY3
# Tarefa Sentinel-1 'sentinel1_grid_cell_1121' iniciada. ID: 5R5OH2GY7HANYWO7UGCYY7V2
#
# --- Analisando Célula 1123/1404 ---
# Nenhuma rodovia encontrada na Célula 1123. Pulando para a próxima...
#
# --- Analisando Célula 1124/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1124.
# Tarefa de Máscara 'mask_grid_cell_1123' iniciada. ID: ZJUPB4GB6NCRVFSOIU6CQWUZ
# Tarefa Sentinel-2 'sentinel2_grid_cell_1123' iniciada. ID: 4G46YVBRWXUS44I5OARAK5SJ
# Tarefa Sentinel-1 'sentinel1_grid_cell_1123' iniciada. ID: FRQT57SJNHXR2BW45NKHWWE7
#
# --- Analisando Célula 1125/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1125.
# Tarefa de Máscara 'mask_grid_cell_1124' iniciada. ID: S2RQNOGXT27VJDLNYINRBBZY
# Tarefa Sentinel-2 'sentinel2_grid_cell_1124' iniciada. ID: QNUQD4ISKUTQUYZ3UWXGARS4
# Tarefa Sentinel-1 'sentinel1_grid_cell_1124' iniciada. ID: Q6JIGDFYGB2Q3SRIBECCY6EY
#
# --- Analisando Célula 1126/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1126.
# Tarefa de Máscara 'mask_grid_cell_1125' iniciada. ID: HM3RNL3P5GAW56OHT5ZMSYYC
# Tarefa Sentinel-2 'sentinel2_grid_cell_1125' iniciada. ID: NSCJ7GV4SF3745UMN3W72ABJ
# Tarefa Sentinel-1 'sentinel1_grid_cell_1125' iniciada. ID: JQ4WQRMI2HPVCWIDEUKZO7AY
#
# --- Analisando Célula 1127/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1127.
# Tarefa de Máscara 'mask_grid_cell_1126' iniciada. ID: Q7O5OXUAYLHREXWL3OK7W42Y
# Tarefa Sentinel-2 'sentinel2_grid_cell_1126' iniciada. ID: LOVJJSXMXMDMWWILUZKPVUOB
# Tarefa Sentinel-1 'sentinel1_grid_cell_1126' iniciada. ID: LVT57BKH2HW27KMNNTUNB3QQ
#
# --- Analisando Célula 1128/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1128.
# Tarefa de Máscara 'mask_grid_cell_1127' iniciada. ID: IWPJILEEGZOYIVEJDOB65G55
# Tarefa Sentinel-2 'sentinel2_grid_cell_1127' iniciada. ID: CWNPTLJXZBKIZFOCOZ7L7VR4
# Tarefa Sentinel-1 'sentinel1_grid_cell_1127' iniciada. ID: 2KXKAMMIYHQAGPCPEUBNGN4U
#
# --- Analisando Célula 1129/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1129.
# Tarefa de Máscara 'mask_grid_cell_1128' iniciada. ID: H6OWMXVI2K5JBFZBTNAE7SJU
# Tarefa Sentinel-2 'sentinel2_grid_cell_1128' iniciada. ID: 2L2LXJ5NV5DWLMPJXNNXXY44
# Tarefa Sentinel-1 'sentinel1_grid_cell_1128' iniciada. ID: G35QYKD2DM3DZVHSYVITTRIU
#
# --- Analisando Célula 1130/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1130.
# Tarefa de Máscara 'mask_grid_cell_1129' iniciada. ID: STK37OPTD35EIKQKOYTIHSXC
# Tarefa Sentinel-2 'sentinel2_grid_cell_1129' iniciada. ID: SU3YM7QPAUT7ZGJYTM772ECM
# Tarefa Sentinel-1 'sentinel1_grid_cell_1129' iniciada. ID: P5SYBIV7E3QGURE5ABVBKOXQ
#
# --- Analisando Célula 1131/1404 ---
# Nenhuma rodovia encontrada na Célula 1131. Pulando para a próxima...
#
# --- Analisando Célula 1132/1404 ---
# Nenhuma rodovia encontrada na Célula 1132. Pulando para a próxima...
#
# --- Analisando Célula 1145/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1145.
# Tarefa de Máscara 'mask_grid_cell_1144' iniciada. ID: 4I3SF6MMQPNPBY4KPEZOELRF
# Tarefa Sentinel-2 'sentinel2_grid_cell_1144' iniciada. ID: UPQFTMGGPXF4Q2H5PLX4CZIZ
# Tarefa Sentinel-1 'sentinel1_grid_cell_1144' iniciada. ID: NPE3326PSTBM5OM5XVKDHB22
#
# --- Analisando Célula 1146/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1146.
# Tarefa de Máscara 'mask_grid_cell_1145' iniciada. ID: PLPHXQIHSTZGSU652ZVNNVSG
# Tarefa Sentinel-2 'sentinel2_grid_cell_1145' iniciada. ID: NYLEX7SWKEAF576GDEWOJ2K5
# Tarefa Sentinel-1 'sentinel1_grid_cell_1145' iniciada. ID: WAA6XIV27QQTPRVXURT7L7JL
#
# --- Analisando Célula 1147/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1147.
# Tarefa de Máscara 'mask_grid_cell_1146' iniciada. ID: ADKQKNPEHF67UU56EKLIIFJL
# Tarefa Sentinel-2 'sentinel2_grid_cell_1146' iniciada. ID: JMJ7SFSSSRCARV54FFRG2CG2
# Tarefa Sentinel-1 'sentinel1_grid_cell_1146' iniciada. ID: H33VYRDZKYV5JSG2PEUDUHYS
#
# --- Analisando Célula 1148/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1148.
# Tarefa de Máscara 'mask_grid_cell_1147' iniciada. ID: 43CQ3LRAPESF7SIZIUNY2GAV
# Tarefa Sentinel-2 'sentinel2_grid_cell_1147' iniciada. ID: IOQB6GPPABO4JJJKU5TSX53B
# Tarefa Sentinel-1 'sentinel1_grid_cell_1147' iniciada. ID: WSEKW7BLNYAWR34HJVVGEDZS
#
# --- Analisando Célula 1149/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1149.
# Tarefa de Máscara 'mask_grid_cell_1148' iniciada. ID: ITXQGJ7CLDBOT7WX3XUGW5CP
# Tarefa Sentinel-2 'sentinel2_grid_cell_1148' iniciada. ID: NO3VZCRLAJE63Q7FRLZ3CRSJ
# Tarefa Sentinel-1 'sentinel1_grid_cell_1148' iniciada. ID: QO5PNRKLSXU5VJBOXOUCAFNU
#
# --- Analisando Célula 1150/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1150.
# Tarefa de Máscara 'mask_grid_cell_1149' iniciada. ID: NNM56VVX6VFZQO3NFALOB23D
# Tarefa Sentinel-2 'sentinel2_grid_cell_1149' iniciada. ID: ICEDELFZRT2LCQFORSZATLYV
# Tarefa Sentinel-1 'sentinel1_grid_cell_1149' iniciada. ID: KLXRA2U24CMQ6UT2RVRFT2TC
#
# --- Analisando Célula 1151/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1151.
# Tarefa de Máscara 'mask_grid_cell_1150' iniciada. ID: X7Y4ALRFWSUJVVCEVYHA4PEQ
# Tarefa Sentinel-2 'sentinel2_grid_cell_1150' iniciada. ID: OJESQ55GOMI6UYUX3EOVR3CK
# Tarefa Sentinel-1 'sentinel1_grid_cell_1150' iniciada. ID: L2DACCTJQ7DRIVGJQXABUKEN
#
# --- Analisando Célula 1152/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1152.
# Tarefa de Máscara 'mask_grid_cell_1151' iniciada. ID: HUB5AYXCENDSS44IS5IKFFIL
# Tarefa Sentinel-2 'sentinel2_grid_cell_1151' iniciada. ID: NHPE2Y5C5SJK3KBSJDJZUWTJ
# Tarefa Sentinel-1 'sentinel1_grid_cell_1151' iniciada. ID: 6AIBMDF3OWAX5YPXRDBF7YWJ
#
# --- Analisando Célula 1153/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1153.
# Tarefa de Máscara 'mask_grid_cell_1152' iniciada. ID: NDMDH3LOQPTGTMN2QW5WR6I3
# Tarefa Sentinel-2 'sentinel2_grid_cell_1152' iniciada. ID: 36CQ6QLUZO766W4XY55WL7JJ
# Tarefa Sentinel-1 'sentinel1_grid_cell_1152' iniciada. ID: QLP7J4ZT34XAYQME2GOJBN6M
#
# --- Analisando Célula 1154/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1154.
# Tarefa de Máscara 'mask_grid_cell_1153' iniciada. ID: NSLZT4DJ5Z7AKCSRIBAYZCDV
# Tarefa Sentinel-2 'sentinel2_grid_cell_1153' iniciada. ID: JRMYOTG5XPJFT3TQ63FVO674
# Tarefa Sentinel-1 'sentinel1_grid_cell_1153' iniciada. ID: 4LYS3PKYRWNTYF25L5TDG33J
#
# --- Analisando Célula 1155/1404 ---
# Nenhuma rodovia encontrada na Célula 1155. Pulando para a próxima...
#
# --- Analisando Célula 1156/1404 ---
# Nenhuma rodovia encontrada na Célula 1156. Pulando para a próxima...
#
# --- Analisando Célula 1157/1404 ---
# Nenhuma rodovia encontrada na Célula 1157. Pulando para a próxima...
#
# --- Analisando Célula 1158/1404 ---
# Nenhuma rodovia encontrada na Célula 1158. Pulando para a próxima...
#
# --- Analisando Célula 1159/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1159.
# Tarefa de Máscara 'mask_grid_cell_1158' iniciada. ID: ZLXIZGRGSDJ64ZA52KNABG2A
# Tarefa Sentinel-2 'sentinel2_grid_cell_1158' iniciada. ID: GO7K7LWA6HP2ONJ5LF5NTBL5
# Tarefa Sentinel-1 'sentinel1_grid_cell_1158' iniciada. ID: OY5GWUFE7RQM7ME3VRW6WD4U
#
# --- Analisando Célula 1160/1404 ---
# Nenhuma rodovia encontrada na Célula 1160. Pulando para a próxima...
#
# --- Analisando Célula 1161/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1161.
# Tarefa de Máscara 'mask_grid_cell_1160' iniciada. ID: 24CL7ZIWSQFSIDXYWIPQW5JD
# Tarefa Sentinel-2 'sentinel2_grid_cell_1160' iniciada. ID: F2ZPQNZXH3DWT2LWHQPVI3RV
# Tarefa Sentinel-1 'sentinel1_grid_cell_1160' iniciada. ID: BVE3UJNUTAK22G5FQVJ3DR2H
#
# --- Analisando Célula 1162/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1162.
# Tarefa de Máscara 'mask_grid_cell_1161' iniciada. ID: CIE4MGWU5X6PUZXEGWUEDVGX
# Tarefa Sentinel-2 'sentinel2_grid_cell_1161' iniciada. ID: 5G3B7KWTNPSOEIYVCJ7577LW
# Tarefa Sentinel-1 'sentinel1_grid_cell_1161' iniciada. ID: FS4FWSW3IAJEHVNAU7U34VLE
#
# --- Analisando Célula 1163/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1163.
# Tarefa de Máscara 'mask_grid_cell_1162' iniciada. ID: 2JFSCMHUHRDNTQIV7LBHDXFP
# Tarefa Sentinel-2 'sentinel2_grid_cell_1162' iniciada. ID: OSSAMHK77WIPF5OV6SCXN3CM
# Tarefa Sentinel-1 'sentinel1_grid_cell_1162' iniciada. ID: I4O6DJ665VZPQZ2PMIX47WAV
#
# --- Analisando Célula 1164/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1164.
# Tarefa de Máscara 'mask_grid_cell_1163' iniciada. ID: 4CUY6EAVJU7CDZV242ZBE7CS
# Tarefa Sentinel-2 'sentinel2_grid_cell_1163' iniciada. ID: EKB3LFBJU2NQVGHOEYQCU6BB
# Tarefa Sentinel-1 'sentinel1_grid_cell_1163' iniciada. ID: MJXLYQWEU5TJ5FPZEB3IZTXL
#
# --- Analisando Célula 1165/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1165.
# Tarefa de Máscara 'mask_grid_cell_1164' iniciada. ID: TTUDWETMIQIEONGTW4BP6ZVT
# Tarefa Sentinel-2 'sentinel2_grid_cell_1164' iniciada. ID: 6OJTL4RLF3H42HQMBVDTIIQ6
# Tarefa Sentinel-1 'sentinel1_grid_cell_1164' iniciada. ID: SMIUW33MHVGESL2BRMCKQWD6
#
# --- Analisando Célula 1166/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1166.
# Tarefa de Máscara 'mask_grid_cell_1165' iniciada. ID: MLXGHVOXEYJMUU6IGDTDQWXJ
# Tarefa Sentinel-2 'sentinel2_grid_cell_1165' iniciada. ID: QRXXM4KPRFVBK3JU7CQWDSVV
# Tarefa Sentinel-1 'sentinel1_grid_cell_1165' iniciada. ID: SLPDXRQ7CS6S2H323HZZVCFD
#
# --- Analisando Célula 1167/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1167.
# Tarefa de Máscara 'mask_grid_cell_1166' iniciada. ID: ZXXBB7HN7OSXRIHOPQXXQ5VE
# Tarefa Sentinel-2 'sentinel2_grid_cell_1166' iniciada. ID: YTKD6NXOWZICREG732D6B76K
# Tarefa Sentinel-1 'sentinel1_grid_cell_1166' iniciada. ID: HUMR2G3UIVVVEHF2D5FZEXKB
#
# --- Analisando Célula 1168/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1168.
# Tarefa de Máscara 'mask_grid_cell_1167' iniciada. ID: N7PKTWIG2GAYMY7DQRVOJWPM
# Tarefa Sentinel-2 'sentinel2_grid_cell_1167' iniciada. ID: PRHTEB3TFQZOFRBNZA2VP2SM
# Tarefa Sentinel-1 'sentinel1_grid_cell_1167' iniciada. ID: WTQF35ZUFK2HVFJZR6EWCIC2
#
# --- Analisando Célula 1169/1404 ---
# Nenhuma rodovia encontrada na Célula 1169. Pulando para a próxima...
#
# --- Analisando Célula 1170/1404 ---
# Nenhuma rodovia encontrada na Célula 1170. Pulando para a próxima...
#
# --- Analisando Célula 1184/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1184.
# Tarefa de Máscara 'mask_grid_cell_1183' iniciada. ID: 6IGYPJJLHGA7W4ETCVIUYNCZ
# Tarefa Sentinel-2 'sentinel2_grid_cell_1183' iniciada. ID: TB576QAGK2AGM2U3WDMQBUUN
# Tarefa Sentinel-1 'sentinel1_grid_cell_1183' iniciada. ID: TSVVFTRYXXAEVBODUFLFZGJQ
#
# --- Analisando Célula 1185/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1185.
# Tarefa de Máscara 'mask_grid_cell_1184' iniciada. ID: E3EOZDNREH7AN3IVG2MMQO53
# Tarefa Sentinel-2 'sentinel2_grid_cell_1184' iniciada. ID: SSRNVIEOVIRYVKTANZQXBDEN
# Tarefa Sentinel-1 'sentinel1_grid_cell_1184' iniciada. ID: L3JR6CJR6GIKN6LNTFBXOQ3A
#
# --- Analisando Célula 1186/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1186.
# Tarefa de Máscara 'mask_grid_cell_1185' iniciada. ID: FHYQBZKECH7DEE6YWUITE3UT
# Tarefa Sentinel-2 'sentinel2_grid_cell_1185' iniciada. ID: CZQNIGPEMNZFF6EVIEAE7JAZ
# Tarefa Sentinel-1 'sentinel1_grid_cell_1185' iniciada. ID: SULXEDSUTAOURJWZLNLA3E5F
#
# --- Analisando Célula 1187/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1187.
# Tarefa de Máscara 'mask_grid_cell_1186' iniciada. ID: DWB2T43GWDCJLTR4FGXNYYES
# Tarefa Sentinel-2 'sentinel2_grid_cell_1186' iniciada. ID: QTZWQXNGOA4EQ67IPCXPG4RR
# Tarefa Sentinel-1 'sentinel1_grid_cell_1186' iniciada. ID: X5D5JXBYDRSWSGSPN5ED7JMO
#
# --- Analisando Célula 1188/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1188.
# Tarefa de Máscara 'mask_grid_cell_1187' iniciada. ID: RDCP54HDKODZWEMHHJRFG62W
# Tarefa Sentinel-2 'sentinel2_grid_cell_1187' iniciada. ID: X7VQHIEFBD477QANHD5PNAOP
# Tarefa Sentinel-1 'sentinel1_grid_cell_1187' iniciada. ID: TXNC5CLI3HQFHMIIHP6GY6G4
#
# --- Analisando Célula 1189/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1189.
# Tarefa de Máscara 'mask_grid_cell_1188' iniciada. ID: V2YZ5EJRDSCJDJK7N7LERK7A
# Tarefa Sentinel-2 'sentinel2_grid_cell_1188' iniciada. ID: JCWXNLYIJ7MMHP4ZYBU5XGPN
# Tarefa Sentinel-1 'sentinel1_grid_cell_1188' iniciada. ID: ZJVUUSALKK5TIX6266WYA5CE
#
# --- Analisando Célula 1190/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1190.
# Tarefa de Máscara 'mask_grid_cell_1189' iniciada. ID: QIW5ODFYDIXMFUSUP34IQLOC
# Tarefa Sentinel-2 'sentinel2_grid_cell_1189' iniciada. ID: 4NXIBQ662RMP6QNU2SQT3XOD
# Tarefa Sentinel-1 'sentinel1_grid_cell_1189' iniciada. ID: RSMR3CAVDRKSVNPJIHYCFZOR
#
# --- Analisando Célula 1191/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1191.
# Tarefa de Máscara 'mask_grid_cell_1190' iniciada. ID: YVWQCL6ZOL6BQGSZ6FAWQGKK
# Tarefa Sentinel-2 'sentinel2_grid_cell_1190' iniciada. ID: 22OEEYSRDJAQJMJ3MEZUFM3O
# Tarefa Sentinel-1 'sentinel1_grid_cell_1190' iniciada. ID: U6V5VMIE33ZJEOEI4MDIOX4U
#
# --- Analisando Célula 1192/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1192.
# Tarefa de Máscara 'mask_grid_cell_1191' iniciada. ID: IYNU624KZZIFY4W7QA5ODFUD
# Tarefa Sentinel-2 'sentinel2_grid_cell_1191' iniciada. ID: FDFHJBOCEIJ3ZRIU7OAXSSK2
# Tarefa Sentinel-1 'sentinel1_grid_cell_1191' iniciada. ID: E7VHDYCAID2EWZYTBTEPWIXN
#
# --- Analisando Célula 1193/1404 ---
# Nenhuma rodovia encontrada na Célula 1193. Pulando para a próxima...
#
# --- Analisando Célula 1194/1404 ---
# Nenhuma rodovia encontrada na Célula 1194. Pulando para a próxima...
#
# --- Analisando Célula 1195/1404 ---
# Nenhuma rodovia encontrada na Célula 1195. Pulando para a próxima...
#
# --- Analisando Célula 1196/1404 ---
# Nenhuma rodovia encontrada na Célula 1196. Pulando para a próxima...
#
# --- Analisando Célula 1197/1404 ---
# Nenhuma rodovia encontrada na Célula 1197. Pulando para a próxima...
#
# --- Analisando Célula 1198/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1198.
# Tarefa de Máscara 'mask_grid_cell_1197' iniciada. ID: YKHX23TP5CPCTIB4WZYYGCWN
# Tarefa Sentinel-2 'sentinel2_grid_cell_1197' iniciada. ID: D3HFDFGXNQW5TVKZQQAZITQH
# Tarefa Sentinel-1 'sentinel1_grid_cell_1197' iniciada. ID: OEFM72YLYI4YF6UBPM3IHN3U
#
# --- Analisando Célula 1199/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1199.
# Tarefa de Máscara 'mask_grid_cell_1198' iniciada. ID: 24M4SFXYYZ6FH64LEU4XYT6Z
# Tarefa Sentinel-2 'sentinel2_grid_cell_1198' iniciada. ID: 337LLYQQWEGEX33B3TQAQK3Z
# Tarefa Sentinel-1 'sentinel1_grid_cell_1198' iniciada. ID: 4YQSG52ZX7IE6AI6DYTGJB5L
#
# --- Analisando Célula 1200/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1200.
# Tarefa de Máscara 'mask_grid_cell_1199' iniciada. ID: YKF2MLN2FMQDR73M65K5B57M
# Tarefa Sentinel-2 'sentinel2_grid_cell_1199' iniciada. ID: OVQRETZLVB3XHD5EPSVSRQ5Y
# Tarefa Sentinel-1 'sentinel1_grid_cell_1199' iniciada. ID: 7ML6LFTHIZ7NWWUAVMXX6ZGG
#
# --- Analisando Célula 1201/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1201.
# Tarefa de Máscara 'mask_grid_cell_1200' iniciada. ID: BM64TUFIFUZUXMTME27FWK3P
# Tarefa Sentinel-2 'sentinel2_grid_cell_1200' iniciada. ID: ATUTFPTQVAVAGEGIBRJOEFSE
# Tarefa Sentinel-1 'sentinel1_grid_cell_1200' iniciada. ID: 3ZL7AUTSUEO7MPRHSFWUMBMM
#
# --- Analisando Célula 1202/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1202.
# Tarefa de Máscara 'mask_grid_cell_1201' iniciada. ID: DJSCWNPS2HPDKSVC36Z2CD44
# Tarefa Sentinel-2 'sentinel2_grid_cell_1201' iniciada. ID: UNKK2FLGCAXVHC4IV7BZPAJE
# Tarefa Sentinel-1 'sentinel1_grid_cell_1201' iniciada. ID: ZAINNNSLGKSFS57PQ426QHT2
#
# --- Analisando Célula 1203/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1203.
# Tarefa de Máscara 'mask_grid_cell_1202' iniciada. ID: CPBES3YD72SDBXGN4AMPZQH3
# Tarefa Sentinel-2 'sentinel2_grid_cell_1202' iniciada. ID: DMDZPWZHQQLDTHQZD3Q3CNNY
# Tarefa Sentinel-1 'sentinel1_grid_cell_1202' iniciada. ID: XBOU4QZWN4WAEXUBGTTB3TOP
#
# --- Analisando Célula 1204/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1204.
# Tarefa de Máscara 'mask_grid_cell_1203' iniciada. ID: GHGUAEZCQWVBZEORTADGQH37
# Tarefa Sentinel-2 'sentinel2_grid_cell_1203' iniciada. ID: 5SNDLULOYPYXUOLY4EQERVDO
# Tarefa Sentinel-1 'sentinel1_grid_cell_1203' iniciada. ID: ZNBGJB7JB4NRALMNCRZLUTCS
#
# --- Analisando Célula 1205/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1205.
# Tarefa de Máscara 'mask_grid_cell_1204' iniciada. ID: OZE2TGD243B5VIRO6LP2FEQ4
# Tarefa Sentinel-2 'sentinel2_grid_cell_1204' iniciada. ID: 2SWILS2VUHQBUWDWJ3ZY2F7I
# Tarefa Sentinel-1 'sentinel1_grid_cell_1204' iniciada. ID: IOP674HLNPHWQAFMHGSRCPCL
#
# --- Analisando Célula 1206/1404 ---
# Nenhuma rodovia encontrada na Célula 1206. Pulando para a próxima...
#
# --- Analisando Célula 1207/1404 ---
# Nenhuma rodovia encontrada na Célula 1207. Pulando para a próxima...
#
# --- Analisando Célula 1208/1404 ---
# Nenhuma rodovia encontrada na Célula 1208. Pulando para a próxima...
#
# --- Analisando Célula 1222/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1222.
# Tarefa de Máscara 'mask_grid_cell_1221' iniciada. ID: VPYOUPUFQNXMHK6ZKKGCTESH
# Tarefa Sentinel-2 'sentinel2_grid_cell_1221' iniciada. ID: TSN2RJRK2ZBK6SBRLAMNBDWM
# Tarefa Sentinel-1 'sentinel1_grid_cell_1221' iniciada. ID: VBJQDULRVU7DCXGBW7T7IFSN
#
# --- Analisando Célula 1223/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1223.
# Tarefa de Máscara 'mask_grid_cell_1222' iniciada. ID: OQ2J5CACWQMNWUTT2D4FWPPS
# Tarefa Sentinel-2 'sentinel2_grid_cell_1222' iniciada. ID: ZTBXJS6RPFOJ7F2S7OL646X5
# Tarefa Sentinel-1 'sentinel1_grid_cell_1222' iniciada. ID: EO3KSMKFKU3AGCDORQXOGG4N
#
# --- Analisando Célula 1224/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1224.
# Tarefa de Máscara 'mask_grid_cell_1223' iniciada. ID: 3OP4Y5ZJ3JQX22KEPXOTWDTX
# Tarefa Sentinel-2 'sentinel2_grid_cell_1223' iniciada. ID: PAUIYKFXBIABYSOVMLGMDWGD
# Tarefa Sentinel-1 'sentinel1_grid_cell_1223' iniciada. ID: J6EBAZGA3STXUFB7I4SD46VD
#
# --- Analisando Célula 1225/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1225.
# Tarefa de Máscara 'mask_grid_cell_1224' iniciada. ID: XE6QOSIVPLVAWZORYIY6T7VP
# Tarefa Sentinel-2 'sentinel2_grid_cell_1224' iniciada. ID: UDRYFMULX27CKFCASSTKQIWO
# Tarefa Sentinel-1 'sentinel1_grid_cell_1224' iniciada. ID: PZW744RT32L2DGLNOJDFDNJM
#
# --- Analisando Célula 1226/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1226.
# Tarefa de Máscara 'mask_grid_cell_1225' iniciada. ID: 7DT3U57YGSTCKYALBLFQFXLB
# Tarefa Sentinel-2 'sentinel2_grid_cell_1225' iniciada. ID: TG6FO5NVFIXJQ2VRVS3ZC4U3
# Tarefa Sentinel-1 'sentinel1_grid_cell_1225' iniciada. ID: 3K4OZ52N7PR6SVANJ7NXE4LK
#
# --- Analisando Célula 1227/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1227.
# Tarefa de Máscara 'mask_grid_cell_1226' iniciada. ID: Z5OPMWKBKDLTINUFFKLXGAIU
# Tarefa Sentinel-2 'sentinel2_grid_cell_1226' iniciada. ID: 7FVAES7B52IV4FI3JLWSXHIM
# Tarefa Sentinel-1 'sentinel1_grid_cell_1226' iniciada. ID: 3VXSXE4WQ3LC5MWQBGXN3AP3
#
# --- Analisando Célula 1228/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1228.
# Tarefa de Máscara 'mask_grid_cell_1227' iniciada. ID: H3LAYFN3OZYP35OSXGDRPTED
# Tarefa Sentinel-2 'sentinel2_grid_cell_1227' iniciada. ID: BJQLTPQTY4YTNORNAOGSHQU3
# Tarefa Sentinel-1 'sentinel1_grid_cell_1227' iniciada. ID: MRAAY2VOC2NDXQJBKMAHIWXT
#
# --- Analisando Célula 1229/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1229.
# Tarefa de Máscara 'mask_grid_cell_1228' iniciada. ID: OMT6XTID7EFZYSHTC7JU7NWQ
# Tarefa Sentinel-2 'sentinel2_grid_cell_1228' iniciada. ID: 42MXF4AWNUKK526Z3VOBZP6E
# Tarefa Sentinel-1 'sentinel1_grid_cell_1228' iniciada. ID: MV4SR7WMD5OIRXHQ6JQPGIDD
#
# --- Analisando Célula 1230/1404 ---
# Nenhuma rodovia encontrada na Célula 1230. Pulando para a próxima...
#
# --- Analisando Célula 1231/1404 ---
# Nenhuma rodovia encontrada na Célula 1231. Pulando para a próxima...
#
# --- Analisando Célula 1232/1404 ---
# Nenhuma rodovia encontrada na Célula 1232. Pulando para a próxima...
#
# --- Analisando Célula 1233/1404 ---
# Nenhuma rodovia encontrada na Célula 1233. Pulando para a próxima...
#
# --- Analisando Célula 1234/1404 ---
# Nenhuma rodovia encontrada na Célula 1234. Pulando para a próxima...
#
# --- Analisando Célula 1235/1404 ---
# Nenhuma rodovia encontrada na Célula 1235. Pulando para a próxima...
#
# --- Analisando Célula 1236/1404 ---
# Nenhuma rodovia encontrada na Célula 1236. Pulando para a próxima...
#
# --- Analisando Célula 1237/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1237.
# Tarefa de Máscara 'mask_grid_cell_1236' iniciada. ID: 6QMAAVVQULLF2YVHLKQDPANY
# Tarefa Sentinel-2 'sentinel2_grid_cell_1236' iniciada. ID: WUK2N7F4LOUNZPN6HIGCWKNT
# Tarefa Sentinel-1 'sentinel1_grid_cell_1236' iniciada. ID: TE3Z6AB56AXCELEQ2OGXWP3C
#
# --- Analisando Célula 1238/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1238.
# Tarefa de Máscara 'mask_grid_cell_1237' iniciada. ID: KYYRKTP5XMAG5C5HMAXWDMEE
# Tarefa Sentinel-2 'sentinel2_grid_cell_1237' iniciada. ID: 6XVHRFVSURSHSW66VAT7GPIZ
# Tarefa Sentinel-1 'sentinel1_grid_cell_1237' iniciada. ID: VMTKJSZ4FW6GUUCNCSPYXQUV
#
# --- Analisando Célula 1239/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1239.
# Tarefa de Máscara 'mask_grid_cell_1238' iniciada. ID: XKYXZRNGDIU2KYNBIGRKQDX7
# Tarefa Sentinel-2 'sentinel2_grid_cell_1238' iniciada. ID: JZWIVWPYQMPZNHI5EGABSWU3
# Tarefa Sentinel-1 'sentinel1_grid_cell_1238' iniciada. ID: OMXDMXRMECZRR4EBFIQMAWA3
#
# --- Analisando Célula 1240/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1240.
# Tarefa de Máscara 'mask_grid_cell_1239' iniciada. ID: XGV2SWD5PZ4JPC3Y72KGCJST
# Tarefa Sentinel-2 'sentinel2_grid_cell_1239' iniciada. ID: 72DU3JQS2MGF3CXQBX36OKFX
# Tarefa Sentinel-1 'sentinel1_grid_cell_1239' iniciada. ID: SZTAJ67CLLELFMLRD4MZ34FP
#
# --- Analisando Célula 1241/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1241.
# Tarefa de Máscara 'mask_grid_cell_1240' iniciada. ID: CFLY4VC3RXFMNNVFICKMHM4W
# Tarefa Sentinel-2 'sentinel2_grid_cell_1240' iniciada. ID: 4X2DEF226DORW4X26HGYXW5O
# Tarefa Sentinel-1 'sentinel1_grid_cell_1240' iniciada. ID: AMOQJ76BXR3KDJ2N24TAZELX
#
# --- Analisando Célula 1242/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1242.
# Tarefa de Máscara 'mask_grid_cell_1241' iniciada. ID: HJ56OVFX7KBK5BQAWBM7GY5P
# Tarefa Sentinel-2 'sentinel2_grid_cell_1241' iniciada. ID: BHCCAAK2WCNQ3BFXLUI7CSIP
# Tarefa Sentinel-1 'sentinel1_grid_cell_1241' iniciada. ID: 23IOZ7EW2HTRVSQFVJ4SSHYS
#
# --- Analisando Célula 1243/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1243.
# Tarefa de Máscara 'mask_grid_cell_1242' iniciada. ID: ZOGD6BPAIV577JKSZGMSTIBF
# Tarefa Sentinel-2 'sentinel2_grid_cell_1242' iniciada. ID: AYWSCSZFIX3LNKL5KACRJCYI
# Tarefa Sentinel-1 'sentinel1_grid_cell_1242' iniciada. ID: JPPUJNUF2Q3HMWYR6NQGDR36
#
# --- Analisando Célula 1244/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1244.
# Tarefa de Máscara 'mask_grid_cell_1243' iniciada. ID: DNSN6A2U6Z6OS3THLTCY5TS3
# Tarefa Sentinel-2 'sentinel2_grid_cell_1243' iniciada. ID: R5GLAJUAWUDNYL6AAAQDH5DK
# Tarefa Sentinel-1 'sentinel1_grid_cell_1243' iniciada. ID: 2YVQWHSXB2AOMOXFCQ5T7KCM
#
# --- Analisando Célula 1245/1404 ---
# Nenhuma rodovia encontrada na Célula 1245. Pulando para a próxima...
#
# --- Analisando Célula 1259/1404 ---
# Nenhuma rodovia encontrada na Célula 1259. Pulando para a próxima...
#
# --- Analisando Célula 1260/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1260.
# Tarefa de Máscara 'mask_grid_cell_1259' iniciada. ID: 24TG4ILWR7YAR3VXZ3AQ6P3U
# Tarefa Sentinel-2 'sentinel2_grid_cell_1259' iniciada. ID: H6XWVEMPHXHPSKKNESKSU6IK
# Tarefa Sentinel-1 'sentinel1_grid_cell_1259' iniciada. ID: 3PBWGXDMI3YDKMDJZXL36D6B
#
# --- Analisando Célula 1261/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1261.
# Tarefa de Máscara 'mask_grid_cell_1260' iniciada. ID: GXYIKYND7ZQTQJT3TAQPQLHJ
# Tarefa Sentinel-2 'sentinel2_grid_cell_1260' iniciada. ID: IL6RUGG2EKFCCS2ICL6HKBLU
# Tarefa Sentinel-1 'sentinel1_grid_cell_1260' iniciada. ID: ACKQSQENUJENFCT3L35PYEAG
#
# --- Analisando Célula 1262/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1262.
# Tarefa de Máscara 'mask_grid_cell_1261' iniciada. ID: K2FATZVMXV77GTOWV4P4U5TJ
# Tarefa Sentinel-2 'sentinel2_grid_cell_1261' iniciada. ID: N76HEM4YTT5JU5VWVMSCAJRP
# Tarefa Sentinel-1 'sentinel1_grid_cell_1261' iniciada. ID: ZM73LR5P46WFMNKPXOFFFEBT
#
# --- Analisando Célula 1263/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1263.
# Tarefa de Máscara 'mask_grid_cell_1262' iniciada. ID: OGISIYC7LVWZZJRINHYHVX7X
# Tarefa Sentinel-2 'sentinel2_grid_cell_1262' iniciada. ID: K4WBTUGEXG6EUHEYAW6QJQ5B
# Tarefa Sentinel-1 'sentinel1_grid_cell_1262' iniciada. ID: CD5D2IXKNKF37PCO5RJT73EZ
#
# --- Analisando Célula 1264/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1264.
# Tarefa de Máscara 'mask_grid_cell_1263' iniciada. ID: C5E2LOQBEO2SDYHU4NOPL6VR
# Tarefa Sentinel-2 'sentinel2_grid_cell_1263' iniciada. ID: BFDPDVQUFISIAJGRETPHZLQP
# Tarefa Sentinel-1 'sentinel1_grid_cell_1263' iniciada. ID: ZJ6JXRP676FGHHYOU27GCH6X
#
# --- Analisando Célula 1265/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1265.
# Tarefa de Máscara 'mask_grid_cell_1264' iniciada. ID: FJ6PBT3BD6IN64A4BOJWKQQU
# Tarefa Sentinel-2 'sentinel2_grid_cell_1264' iniciada. ID: GAMRXA6XOU2MIG4ACI7AMNXX
# Tarefa Sentinel-1 'sentinel1_grid_cell_1264' iniciada. ID: 5ZCAI3IN4A4PKS4G4CQ42TUS
#
# --- Analisando Célula 1266/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 1266.
# Tarefa de Máscara 'mask_grid_cell_1265' iniciada. ID: OW65UXHGJRA5NVVWKPXGVFVH
# Tarefa Sentinel-2 'sentinel2_grid_cell_1265' iniciada. ID: BSBRRELAZBHSMA43NZRT2CQC
# Tarefa Sentinel-1 'sentinel1_grid_cell_1265' iniciada. ID: XBDOUXKTREID3OZ5GO45A7RU
#
# --- Analisando Célula 1267/1404 ---
# Nenhuma rodovia encontrada na Célula 1267. Pulando para a próxima...
#
# --- Analisando Célula 1268/1404 ---
# ...
# Tarefa Sentinel-1 'sentinel1_grid_cell_2408' iniciada. ID: 3VDPVTJGIC66HY5SZDBZSEBA
#
# --- Analisando Célula 2410/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2410.
# Tarefa de Máscara 'mask_grid_cell_2409' iniciada. ID: TTSXSSA4ACJ7BQG7QVDST4OD
# Tarefa Sentinel-2 'sentinel2_grid_cell_2409' iniciada. ID: Y7FKZSHVQWQLP2MPNA46H7J3
# Tarefa Sentinel-1 'sentinel1_grid_cell_2409' iniciada. ID: 73NZXJ5EDYI65PNT6WOMH7PH
#
# --- Analisando Célula 2411/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2411.
# Tarefa de Máscara 'mask_grid_cell_2410' iniciada. ID: HJB4DDNPJ7A75NZPU62QQ7SY
# Tarefa Sentinel-2 'sentinel2_grid_cell_2410' iniciada. ID: GLOHJPUVVC6XYFQE7BKGUTXU
# Tarefa Sentinel-1 'sentinel1_grid_cell_2410' iniciada. ID: V4BHDJ36QGTFLJXBJBVUVWKP
#
# --- Analisando Célula 2412/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2412.
# Tarefa de Máscara 'mask_grid_cell_2411' iniciada. ID: PAU25YIUTQBMETCR6LVLW6CK
# Tarefa Sentinel-2 'sentinel2_grid_cell_2411' iniciada. ID: H4KSFHXC7UWJ3UZRFVJZZKCK
# Tarefa Sentinel-1 'sentinel1_grid_cell_2411' iniciada. ID: 6R7ZI4YKYEYRIW3DHZ3BIM7V
#
# --- Analisando Célula 2413/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2413.
# Tarefa de Máscara 'mask_grid_cell_2412' iniciada. ID: W6NQMNUE6KBHPGBNJW6KNWCJ
# Tarefa Sentinel-2 'sentinel2_grid_cell_2412' iniciada. ID: HFEJQE75Y2BAF47LVMPAQOLQ
# Tarefa Sentinel-1 'sentinel1_grid_cell_2412' iniciada. ID: HZG25GOYW6RO2AJVJCI37XB3
#
# --- Analisando Célula 2414/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2414.
# Tarefa de Máscara 'mask_grid_cell_2413' iniciada. ID: MLOHGBN7KVBZUPP3W3MJKRGZ
# Tarefa Sentinel-2 'sentinel2_grid_cell_2413' iniciada. ID: 6CQQJ2UYXF3RESJ4WPBTFSSZ
# Tarefa Sentinel-1 'sentinel1_grid_cell_2413' iniciada. ID: CCYB3ATDME5S3MFE4SQXRMGN
#
# --- Analisando Célula 2415/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2415.
# Tarefa de Máscara 'mask_grid_cell_2414' iniciada. ID: VFKA6DTLBJHO364CYX26KVL6
# Tarefa Sentinel-2 'sentinel2_grid_cell_2414' iniciada. ID: YNFHGM77OSZHEQEI2U2XLLXA
# Tarefa Sentinel-1 'sentinel1_grid_cell_2414' iniciada. ID: S4SHHDWPDPJFV7UCDBBD4OJI
#
# --- Analisando Célula 2416/1404 ---
# Nenhuma rodovia encontrada na Célula 2416. Pulando para a próxima...
#
# --- Analisando Célula 2421/1404 ---
# Nenhuma rodovia encontrada na Célula 2421. Pulando para a próxima...
#
# --- Analisando Célula 2422/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2422.
# Tarefa de Máscara 'mask_grid_cell_2421' iniciada. ID: 2RVYSCRN4BZMTIKP5Y4TOYOF
# Tarefa Sentinel-2 'sentinel2_grid_cell_2421' iniciada. ID: TU7WKJUUXNSIIOZ6QNLMD36P
# Tarefa Sentinel-1 'sentinel1_grid_cell_2421' iniciada. ID: BNRZ5J7EX5XDLZ6ET73ITXIX
#
# --- Analisando Célula 2423/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2423.
# Tarefa de Máscara 'mask_grid_cell_2422' iniciada. ID: GHILGXCTXWQ6JOFM2PMVPNXE
# Tarefa Sentinel-2 'sentinel2_grid_cell_2422' iniciada. ID: LQBLXJBRHJCDUZIZMHYFKADH
# Tarefa Sentinel-1 'sentinel1_grid_cell_2422' iniciada. ID: UMO5I7TMFUF4CGCW3VSIAL7O
#
# --- Analisando Célula 2424/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2424.
# Tarefa de Máscara 'mask_grid_cell_2423' iniciada. ID: 6EXF5NMUUTCCOFOFF4LZV44H
# Tarefa Sentinel-2 'sentinel2_grid_cell_2423' iniciada. ID: 6M353P6QF4QLFJTIQ3JLXS3T
# Tarefa Sentinel-1 'sentinel1_grid_cell_2423' iniciada. ID: XCGHMZOTXVPYEHRJC4WGJ2PS
#
# --- Analisando Célula 2425/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2425.
# Tarefa de Máscara 'mask_grid_cell_2424' iniciada. ID: GRG7ISTVWEJI6RGO5L7HDBNW
# Tarefa Sentinel-2 'sentinel2_grid_cell_2424' iniciada. ID: MUIR4KGL2WBUKEYLVX7DVUY2
# Tarefa Sentinel-1 'sentinel1_grid_cell_2424' iniciada. ID: KF4IMDOBKKSHVCGJ3UND5EHX
#
# --- Analisando Célula 2426/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2426.
# Tarefa de Máscara 'mask_grid_cell_2425' iniciada. ID: DHPPZOEF5LGDU2MFZXCJTVAD
# Tarefa Sentinel-2 'sentinel2_grid_cell_2425' iniciada. ID: YRM4SO77VX3XMN4HCJKWQ2NW
# Tarefa Sentinel-1 'sentinel1_grid_cell_2425' iniciada. ID: TNPKZAQD6ODANJBWHFALX6XD
#
# --- Analisando Célula 2427/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2427.
# Tarefa de Máscara 'mask_grid_cell_2426' iniciada. ID: KRHJ7O56REE23WY5F3CH5GZW
# Tarefa Sentinel-2 'sentinel2_grid_cell_2426' iniciada. ID: 4MXAAIP7WPPLKTM2AXL3OINL
# Tarefa Sentinel-1 'sentinel1_grid_cell_2426' iniciada. ID: 6WIVNDCI4HMQ7BHYWM3UGOPL
#
# --- Analisando Célula 2428/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2428.
# Tarefa de Máscara 'mask_grid_cell_2427' iniciada. ID: LEZYRLSUEJWISWJ2VJPQYOCD
# Tarefa Sentinel-2 'sentinel2_grid_cell_2427' iniciada. ID: NK72GPXYAA4FI7MU5N2O5EZV
# Tarefa Sentinel-1 'sentinel1_grid_cell_2427' iniciada. ID: JB3P26X6X5ACCDBOCLHNPRT2
#
# --- Analisando Célula 2445/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2445.
# Tarefa de Máscara 'mask_grid_cell_2444' iniciada. ID: YQTHPXK6ERGZG3LBPHKJ6QDD
# Tarefa Sentinel-2 'sentinel2_grid_cell_2444' iniciada. ID: FYABBVZKUS6Y7KPWRFH5CQE3
# Tarefa Sentinel-1 'sentinel1_grid_cell_2444' iniciada. ID: 6M6NWRBO3AU7GEMCIL5FVI3P
#
# --- Analisando Célula 2446/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2446.
# Tarefa de Máscara 'mask_grid_cell_2445' iniciada. ID: Z6T4CAVWTBKTNQO44UIOWXCY
# Tarefa Sentinel-2 'sentinel2_grid_cell_2445' iniciada. ID: UBGUL7UFGNRDPWOJH2UQK2YR
# Tarefa Sentinel-1 'sentinel1_grid_cell_2445' iniciada. ID: LT3H6ZW2QXIG3EIUEWAJM66P
#
# --- Analisando Célula 2447/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2447.
# Tarefa de Máscara 'mask_grid_cell_2446' iniciada. ID: NTDPCCMNLBE3AT56GWN6PIYO
# Tarefa Sentinel-2 'sentinel2_grid_cell_2446' iniciada. ID: AMXQZSVBAGSSL6VY7KZK4Q2E
# Tarefa Sentinel-1 'sentinel1_grid_cell_2446' iniciada. ID: HHK6UY5FJDZCFGGOB2AW3PSD
#
# --- Analisando Célula 2448/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2448.
# Tarefa de Máscara 'mask_grid_cell_2447' iniciada. ID: RXG5XACFLWJ5KHMU4SEEA2PX
# Tarefa Sentinel-2 'sentinel2_grid_cell_2447' iniciada. ID: AABKSCBMT6UJGMRC7SME3SZX
# Tarefa Sentinel-1 'sentinel1_grid_cell_2447' iniciada. ID: R2SAKYVRGOUXY6FONPF34OWD
#
# --- Analisando Célula 2449/1404 ---
# Nenhuma rodovia encontrada na Célula 2449. Pulando para a próxima...
#
# --- Analisando Célula 2450/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2450.
# Tarefa de Máscara 'mask_grid_cell_2449' iniciada. ID: E6QJ25MLDMLZUJ3EMEZQQUGY
# Tarefa Sentinel-2 'sentinel2_grid_cell_2449' iniciada. ID: OU6UC32USEJ4FY3G5EODGSTF
# Tarefa Sentinel-1 'sentinel1_grid_cell_2449' iniciada. ID: 62BSDELVAVB3WI3RR2AAVJO4
#
# --- Analisando Célula 2451/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2451.
# Tarefa de Máscara 'mask_grid_cell_2450' iniciada. ID: 26NQG7G5KLHS3E4UQI65QTTR
# Tarefa Sentinel-2 'sentinel2_grid_cell_2450' iniciada. ID: CAID5DTLLX4NCR6ZTFHHO3UL
# Tarefa Sentinel-1 'sentinel1_grid_cell_2450' iniciada. ID: NV6SCOXZTECUWWPT7C7MVUG7
#
# --- Analisando Célula 2452/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2452.
# Tarefa de Máscara 'mask_grid_cell_2451' iniciada. ID: DDXHRHITN2N3JG4WH2BCGCYT
# Tarefa Sentinel-2 'sentinel2_grid_cell_2451' iniciada. ID: QLDS7ONQYT6766SZQFPSRZIP
# Tarefa Sentinel-1 'sentinel1_grid_cell_2451' iniciada. ID: ECIW3XKSROJESKIZD5I6RQSN
#
# --- Analisando Célula 2453/1404 ---
# Nenhuma rodovia encontrada na Célula 2453. Pulando para a próxima...
#
# --- Analisando Célula 2454/1404 ---
# Nenhuma rodovia encontrada na Célula 2454. Pulando para a próxima...
#
# --- Analisando Célula 2459/1404 ---
# Nenhuma rodovia encontrada na Célula 2459. Pulando para a próxima...
#
# --- Analisando Célula 2460/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2460.
# Tarefa de Máscara 'mask_grid_cell_2459' iniciada. ID: AMEJFOTGKETPAODPFFQC6NFQ
# Tarefa Sentinel-2 'sentinel2_grid_cell_2459' iniciada. ID: SVS6CA3BSZNZ2XLIF7WWAFAB
# Tarefa Sentinel-1 'sentinel1_grid_cell_2459' iniciada. ID: OLCNXURR4ACS3JZ2ACSZT6DJ
#
# --- Analisando Célula 2461/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2461.
# Tarefa de Máscara 'mask_grid_cell_2460' iniciada. ID: FQAIVUXZIJCUAEASRMED6MEA
# Tarefa Sentinel-2 'sentinel2_grid_cell_2460' iniciada. ID: YWUDZ2ULU656YK62YORP3CZS
# Tarefa Sentinel-1 'sentinel1_grid_cell_2460' iniciada. ID: EECF6SW7I2TPLFJBN77VFY3I
#
# --- Analisando Célula 2462/1404 ---
# Nenhuma rodovia encontrada na Célula 2462. Pulando para a próxima...
#
# --- Analisando Célula 2463/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2463.
# Tarefa de Máscara 'mask_grid_cell_2462' iniciada. ID: S2RY2T7O23EGWZMLCHG3W3VR
# Tarefa Sentinel-2 'sentinel2_grid_cell_2462' iniciada. ID: SB3NBNGAB4LU3UFRIRIYWT5L
# Tarefa Sentinel-1 'sentinel1_grid_cell_2462' iniciada. ID: AKDJGGIBOQDAAJCPAAEF5X6O
#
# --- Analisando Célula 2464/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2464.
# Tarefa de Máscara 'mask_grid_cell_2463' iniciada. ID: NFKINOKZAU66Q2KIHLBWFQ67
# Tarefa Sentinel-2 'sentinel2_grid_cell_2463' iniciada. ID: UKLTYCYRLMZIPGLXQZ7OLYGJ
# Tarefa Sentinel-1 'sentinel1_grid_cell_2463' iniciada. ID: RSQY3XFWLMB2VO7VJXVUJW44
#
# --- Analisando Célula 2465/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2465.
# Tarefa de Máscara 'mask_grid_cell_2464' iniciada. ID: BVYXYF6JSU67BOMNPTSUSK2F
# Tarefa Sentinel-2 'sentinel2_grid_cell_2464' iniciada. ID: R2HVJX32KTKDYEPLNHG2R5SS
# Tarefa Sentinel-1 'sentinel1_grid_cell_2464' iniciada. ID: LZPUGDNE37U5FHRAEQWFHBRT
#
# --- Analisando Célula 2466/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2466.
# Tarefa de Máscara 'mask_grid_cell_2465' iniciada. ID: HB7QBD6SDDGH4G4TGM4HDZ5C
# Tarefa Sentinel-2 'sentinel2_grid_cell_2465' iniciada. ID: XMB3EA46EJ3OJB4ELNPKS2XU
# Tarefa Sentinel-1 'sentinel1_grid_cell_2465' iniciada. ID: 53JFHT2Q6LELAJD4ZC3YS5FS
#
# --- Analisando Célula 2467/1404 ---
# Nenhuma rodovia encontrada na Célula 2467. Pulando para a próxima...
#
# --- Analisando Célula 2483/1404 ---
# Nenhuma rodovia encontrada na Célula 2483. Pulando para a próxima...
#
# --- Analisando Célula 2484/1404 ---
# Nenhuma rodovia encontrada na Célula 2484. Pulando para a próxima...
#
# --- Analisando Célula 2485/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2485.
# Tarefa de Máscara 'mask_grid_cell_2484' iniciada. ID: YMIRWKG646VW7KT2Q6MIAN4O
# Tarefa Sentinel-2 'sentinel2_grid_cell_2484' iniciada. ID: PLTBZB6XPVO655KMILKRNWT2
# Tarefa Sentinel-1 'sentinel1_grid_cell_2484' iniciada. ID: IUATCIJWQT7Z5GQ7MK5G7PXL
#
# --- Analisando Célula 2486/1404 ---
# Nenhuma rodovia encontrada na Célula 2486. Pulando para a próxima...
#
# --- Analisando Célula 2488/1404 ---
# Nenhuma rodovia encontrada na Célula 2488. Pulando para a próxima...
#
# --- Analisando Célula 2489/1404 ---
# Nenhuma rodovia encontrada na Célula 2489. Pulando para a próxima...
#
# --- Analisando Célula 2490/1404 ---
# Nenhuma rodovia encontrada na Célula 2490. Pulando para a próxima...
#
# --- Analisando Célula 2499/1404 ---
# Nenhuma rodovia encontrada na Célula 2499. Pulando para a próxima...
#
# --- Analisando Célula 2500/1404 ---
# Nenhuma rodovia encontrada na Célula 2500. Pulando para a próxima...
#
# --- Analisando Célula 2501/1404 ---
# Nenhuma rodovia encontrada na Célula 2501. Pulando para a próxima...
#
# --- Analisando Célula 2502/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2502.
# Tarefa de Máscara 'mask_grid_cell_2501' iniciada. ID: DGDG6EDO323Q75U6T4E5WI2P
# Tarefa Sentinel-2 'sentinel2_grid_cell_2501' iniciada. ID: JUV6PZWLOSW4THAQIF677QE3
# Tarefa Sentinel-1 'sentinel1_grid_cell_2501' iniciada. ID: EBKDL6PK5KYJIAVLU4FJYTOU
#
# --- Analisando Célula 2503/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2503.
# Tarefa de Máscara 'mask_grid_cell_2502' iniciada. ID: XNCBPWSHHWF5F45E6RDU4GDD
# Tarefa Sentinel-2 'sentinel2_grid_cell_2502' iniciada. ID: ITCWZ3HT7HTRYU5WQC2TGR2W
# Tarefa Sentinel-1 'sentinel1_grid_cell_2502' iniciada. ID: MQRCHFGDW6WZDXLBBWQR3GCN
#
# --- Analisando Célula 2504/1404 ---
# Rodovias encontradas! Iniciando tarefas de download para a célula 2504.
# Tarefa de Máscara 'mask_grid_cell_2503' iniciada. ID: BJ7D4SICQEO6J6NTQVVP7MO7
# Tarefa Sentinel-2 'sentinel2_grid_cell_2503' iniciada. ID: BKMRKFLDODAPSTD363AWNXPO
# Tarefa Sentinel-1 'sentinel1_grid_cell_2503' iniciada. ID: 4EZLHTXAEGSHTXZI55EY6XN3
#
# --- Analisando Célula 2505/1404 ---
# Nenhuma rodovia encontrada na Célula 2505. Pulando para a próxima...
#
# --- Analisando Célula 2510/1404 ---
# Nenhuma rodovia encontrada na Célula 2510. Pulando para a próxima...
#
# --- Analisando Célula 2511/1404 ---
# Nenhuma rodovia encontrada na Célula 2511. Pulando para a próxima...
#
# --- Analisando Célula 2521/1404 ---
# Nenhuma rodovia encontrada na Célula 2521. Pulando para a próxima...
#
# --- Analisando Célula 2523/1404 ---
# Nenhuma rodovia encontrada na Célula 2523. Pulando para a próxima...
#
# --- Analisando Célula 2524/1404 ---
# Nenhuma rodovia encontrada na Célula 2524. Pulando para a próxima...
#
# --- Analisando Célula 2540/1404 ---
# Nenhuma rodovia encontrada na Célula 2540. Pulando para a próxima...
#
# --- Analisando Célula 2541/1404 ---
# Nenhuma rodovia encontrada na Célula 2541. Pulando para a próxima...
#
# --- Analisando Célula 2542/1404 ---
# Nenhuma rodovia encontrada na Célula 2542. Pulando para a próxima...
#
# --- Analisando Célula 2548/1404 ---
# Nenhuma rodovia encontrada na Célula 2548. Pulando para a próxima...
#
# --- Analisando Célula 2579/1404 ---
# Nenhuma rodovia encontrada na Célula 2579. Pulando para a próxima...
#
# --- Analisando Célula 2580/1404 ---
# Nenhuma rodovia encontrada na Célula 2580. Pulando para a próxima...
#
# --- Analisando Célula 2621/1404 ---
# Nenhuma rodovia encontrada na Célula 2621. Pulando para a próxima...
#
# --- Analisando Célula 2653/1404 ---
# Nenhuma rodovia encontrada na Célula 2653. Pulando para a próxima...
#
# --- Analisando Célula 2654/1404 ---
# Nenhuma rodovia encontrada na Célula 2654. Pulando para a próxima...
#
# --- Analisando Célula 2657/1404 ---
# Nenhuma rodovia encontrada na Célula 2657. Pulando para a próxima...
#
# --- Analisando Célula 2658/1404 ---
# Nenhuma rodovia encontrada na Célula 2658. Pulando para a próxima...
#
# --- Analisando Célula 2659/1404 ---
# Nenhuma rodovia encontrada na Célula 2659. Pulando para a próxima...
#
# --- Analisando Célula 2691/1404 ---
# Nenhuma rodovia encontrada na Célula 2691. Pulando para a próxima...
#
# --- Analisando Célula 2692/1404 ---
# Nenhuma rodovia encontrada na Célula 2692. Pulando para a próxima...
#
# --- Analisando Célula 2694/1404 ---
# Nenhuma rodovia encontrada na Célula 2694. Pulando para a próxima...
#
# --- Analisando Célula 2695/1404 ---
# Nenhuma rodovia encontrada na Célula 2695. Pulando para a próxima...
#
# --- Analisando Célula 2696/1404 ---
# Nenhuma rodovia encontrada na Célula 2696. Pulando para a próxima...
#
# --- Analisando Célula 2697/1404 ---
# Nenhuma rodovia encontrada na Célula 2697. Pulando para a próxima...
#
# --- Analisando Célula 2730/1404 ---
# Nenhuma rodovia encontrada na Célula 2730. Pulando para a próxima...
#
# --- Analisando Célula 2731/1404 ---
# Nenhuma rodovia encontrada na Célula 2731. Pulando para a próxima...
#
# --- Analisando Célula 2732/1404 ---
# Nenhuma rodovia encontrada na Célula 2732. Pulando para a próxima...
#
# --- Analisando Célula 2733/1404 ---
# Nenhuma rodovia encontrada na Célula 2733. Pulando para a próxima...
#
# --- Analisando Célula 2734/1404 ---
# Nenhuma rodovia encontrada na Célula 2734. Pulando para a próxima...
#
# --- Analisando Célula 2735/1404 ---
# Nenhuma rodovia encontrada na Célula 2735. Pulando para a próxima...
#
# Processo de inicialização de tarefas concluído para todas as células relevantes da grade!
# Verifique o seu Google Drive e a aba 'Tasks' do Earth Engine para os resultados.
